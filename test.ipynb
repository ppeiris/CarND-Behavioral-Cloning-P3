# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
plt.grid(True)
val_ = [0.0350, 0.0312, 0.0289]
test_ = [0.0403, 0.0323, 0.0276]
plt.xticks([0, 1, 2])
ax.plot(val_, label='validation')
ax.plot(test_, label='test')
ax.legend()
ax.set_xlabel('Epocs')
ax.set_ylabel('Validation/Trining loss')
